# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# Boekh is also a librerary similar as seaborn,matplotlib and plotly. It has numerias tools for the plotting the graphs, which are expressing the meaning of data at a single glance. For using the bekeh, firstly we have to import the some libs as;

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %%
#Glyphs are the building blocks of Bokeh visualizations.
x=[1,4,6,9,3,5,8]
y=[5,3,2,7,8,9,2]

from bokeh.plotting import figure,output_file,show
output_file('graph.html')

p= figure(title= 'Graph')
p.circle(x,y, size=10)
show(p)
# Out:
#   <div id="a293aaf7-ec3c-40cf-97c3-2c695fd8e30b" data-root-id="p1117" style="display: contents;"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.plotting import output_file,figure,show

x=[12,32,54,65,78,23,45]
y=[23,43,54,66,67,82,88]

output_file('customize.html')

p=figure(title= 'Castomize graph ')
p.xaxis.axis_label='This is x axis'
p.yaxis.axis_label='This is y axis'
p.circle(x,y)
show(p)
# Out:
#   <div id="f0a65aaf-3056-41e4-a0c2-12c9b38a0165" data-root-id="p1294" style="display: contents;"></div>

# %%
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.io import curdoc



def scatter_plot():
    source = ColumnDataSource(data=dict(x=[1, 2, 3], y=[4, 5, 6]))
    p = figure(title='Scatter Plot', tools=['pan', 'box_zoom', 'reset'])
    p.scatter(x='x', y='y', source=source, size=10)
    return p


curdoc().add_root(scatter_plot())


# bokeh server --show myapp.py
